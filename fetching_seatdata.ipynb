# %%
#only manual input given to file
#note that 1st letter is always upper case and rest of all are lowercase letters
src_name = "Hyderabad"
dst_name = "Pune"
#delay_days=1
next_day = "14-Jul-2024"


import requests
import pandas as pd
import datetime
import time
import shlex
import os
import json
import numpy as np
import csv

# List of cities with their IDs
cities = {
    "Mumbai": 462,
    "Hyderabad": 124,
    "Bangalore": 122,
    "Chennai": 123,
    "Vizag": 248,
    "Vijayawada": 134,
    "Guntur": 137,
    "Tirupati": 71756,
    "Madurai": 126,
    "Coimbatore": 141,
    "Trichy": 71929,
    "Pondicherry": 233,
    "Pune": 130,
    "Indore": 313,
    "Nagpur": 624,
    "Goa": 210,
    "Warangal": 95479,
    "Nellore": 131,
    "Kochi": 216,
    "Dharwad": 167,
    "Mysore": 129,
    "Mangaluru": 95222,
    "Thiruvananthapuram": 71425
}
#date_of_extraction = (datetime.datetime.now() + datetime.timedelta(days=delay_days))
#next_day = (datetime.datetime.now() + datetime.timedelta(days=delay_days)).strftime('%d-%b-%Y')
main_filepath=fr"C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\{src_name}_to_{dst_name}\data_on_{next_day}"
os.makedirs(main_filepath,exist_ok=True)
next_day
# Out:
# '14-Jul-2024'

# %%
#1 getting different buses in a route
src_id = cities[src_name]
dst_id = cities[dst_name]




def fetch_data(from_city_id, to_city_id, src_name, dst_name, max_retries=10, retry_delay=5):
    #next_day = (datetime.datetime.now() + datetime.timedelta(days=1)).strftime('%d-%b-%Y')
    url = f'https://www.redbus.in/search/SearchV4Results?fromCity={from_city_id}&toCity={to_city_id}&DOJ={next_day}&sectionId=0&groupId=0&limit=0&offset=0&sort=0&sortOrder=0&meta=true&returnSearch=0'
    headers = {
        'accept': 'application/json, text/plain, */*',
        'accept-language': 'en-US,en;q=0.9',
        'content-type': 'application/json',
    }
    
    for attempt in range(max_retries):
        response = requests.post(url, headers=headers)
        if response.status_code == 200:
            return response.json()
        elif response.status_code == 404:
            print(f"404 Not Found: The requested resource for {src_name} to {dst_name} does not exist.")
            return None  # Exit if resource not found
        else:
            print(f"Attempt {attempt + 1}: Access Denied with error code: {response.status_code}")
            time.sleep(retry_delay)  # Wait before the next retry

    print(f"Failed to retrieve data after {max_retries} attempts.")
    return None

#data = fetch_data(src_id, dst_id, src_name, dst_name)
#data


summary_data = []

data = fetch_data(src_id, dst_id, src_name, dst_name)
if data:
        buses_info = [
            {
                    "travelsName": inv['travelsName'],
                    "totalRatings": inv['totalRatings'],
                    "TotaReviews":inv['numberOfReviews'],
                    "departureTime": inv['departureTime'],
                    "arrivalTime": inv['arrivalTime'],
                    "operatorId": inv['operatorId'],
                    "routeId": inv['routeId'],
                    "BusType": inv['busType'],
                    "AC": "YES" if inv.get('isAc', False) else "NO",
                    "Seater": "YES" if inv.get('isSeater', False) else "NO",
                    "Sleeper": "YES" if inv.get('isSleeper', False) else "NO",
            }
                for inv in data.get('inventories', [])
            ]
            
df = pd.DataFrame(buses_info)
# Add extra rows for summaries
total_buses = len(df)
highly_rated_buses = sum(df['totalRatings'] >= 4)
summary_rows = pd.DataFrame({
                "travelsName": ["Total Buses", "Buses Rated >= 4"],
                "totalRatings": [total_buses, highly_rated_buses],
                "departureTime": ["", ""],
                "arrivalTime": ["", ""],
                "operatorId": ["", ""],
                "routeId": ["", ""],
                "BusType": ["", ""],
                "AC": ["", ""],
                "Seater": ["", ""],
                "Sleeper": ["", ""]
            })
df = pd.concat([df, summary_rows], ignore_index=True)
now=datetime.datetime.now()
now = now.strftime("%I%p,%d-%m-%Y")            
filename = f"buses_on_{next_day}_at_{now}.csv"
filepath  = os.path.join(main_filepath,filename)
df.to_csv(filepath, index=False)
print(f"Saved {filename}")
# Out:
# Saved buses_on_14-Jul-2024_at_10AM,09-07-2024.csv

# %%
#2 saving seat data of each bus in diffrent directories
#input for cell : csv file contining different buses
now=datetime.datetime.now()
now = now.strftime("%I%p,%d-%m-%Y")           
filename = f"buses_on_{next_day}_at_{now}.csv"
buses_csv_file_path  = os.path.join(main_filepath,filename)

dummyfilename=f"buses_on_{next_day}"
output_dir=os.path.join(main_filepath,dummyfilename)


#step-1:first setting our curl command
#this function takes tok, fromCityId, toCityId,operator_id,route_id as input and returns curl command important thing for using this function is giving token input argumrnt for the function as it is not taken from any exterior csv files by default im giving token as some value
def generate_curl_command(tok, fromCityId, toCityId,operator_id,route_id):
    # Calculate the next day's date
    #next_day = (datetime.datetime.now() + datetime.timedelta(days=delay_days)).strftime('%d-%b-%Y')    
    # Base cURL command template
    curl_command_template = '''
    curl 'https://www.redbus.in/search/seatlayout/{route_id}/{date}/{operator_id}?isRedDealApplicable=false&tok={tok}&srcCountry=IND&InvPos=1' \
      -H 'accept: application/json, text/plain, */*' \
      -H 'accept-language: en-US,en;q=0.9' \
      -H 'cookie: jfpj=386e43f4851d3c7d15936f880c19eeb7; _gcl_au=1.1.1651692991.1715575898; tvc_smc_bus=google / organic / (not set); mriClientId=WD5c509415-c921-4880-ab5b-ad9a968ccd55; gClId=1195023281.1715575899; rtcInline=V2; dynamic_custinfo=V1; srcCountry=IND; destCountry=IND; _fbp=fb.1.1715575924793.1120299924; srpUserTypeVal=GUEST; singleSeatCoachMark=2; rbuuid=512ed1b0-110b-11ef-98bc-155d27275705; userSessionId=ID_hd5t56d1l; rb_fpData=%7B%22browserName%22%3A%22Chrome%22%2C%22browserVersion%22%3A%22125.0.0.0%22%2C%22os%22%3A%22Windows%22%2C%22osVersion%22%3A%2210%22%2C%22screenSize%22%3A%221536%2C816%22%2C%22screenDPI%22%3A1.25%2C%22screenResolution%22%3A%221920x1080%22%2C%22screenColorDepth%22%3A24%2C%22aspectRatio%22%3A%2216%3A9%22%2C%22systemLanguage%22%3A%22en-US%22%2C%22connection%22%3A%224g%22%2C%22userAgent%22%3A%22mozilla/5.0%20%28windows%20nt%2010.0%3B%20win64%3B%20x64%29%20applewebkit/537.36%20%28khtml%2C%20like%20gecko%29%20chrome/125.0.0.0%20safari/537.36%7CWin32%7Cen-US%22%2C%22timeZone%22%3A5.5%7D; PrimoDetails=%7B%22lastUpdated%22%3A%222024-05-13%22%2C%22lastShown%22%3A%222024-05-21%22%7D; country=IND; currency=INR; defaultlanguage=en; language=en; selectedCurrency=INR; abExps=["rtcInline","dynamic_custinfo"]; abExpsVariants=rtcInline:V2?dynamic_custinfo:V1; tvc_session_alive_bus=1; _gid=GA1.2.319393201.1716373399; _gat_UA-9782412-15=1; _dc_gtm_UA-9782412-15=1; reqOrigin=IND; mriClientIdSetDate=5%2F22%2F24%2010%3A23%3A18%20AM; bCore=1; defaultCountry=IND; deviceSessionId=9ac6deb2-0de7-4b20-bfe8-89d368afde55; mriSessionId=WD64475fb4-f557-48b7-83d0-b25b93f53db5; lzFlag=0; ak_bmsc=E38D836E2B2730F2D6C6BB99391EECB8~000000000000000000000000000000~...; moe_uuid=753cb754-3e23-4350-bf29-e4520bf8dd35; isBrowserFP=true; Branch_BrowserFingerPrintID=1216998847458037070; CountryName=INDIA; _ga=GA1.2.1195023281.1715575899; searchId=9cbe2c87741b4254b9532dde86b82a97; bm_sv=089DFD73A6BC507E91CD2DF0A0D29533~~1; resumeBook=true; _ga_3NXW5V9V8S=GS1.2.1716373399.28.1.1716373424.35.0.0; _VTok={tok}; _ga_1SE754V89Y=GS1.1.1716373398.36.1.1716373424.34.0.117391036' \
      -H 'referer: https://www.redbus.in/search?fromCityId={fromCityId}&srcCountry=IND&toCityId={toCityId}&destCountry=IND&onward={date}&opId=0&busType=Any' \
      -H 'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36' \
 '''
    # Format the cURL command with the provided arguments
    curl_command = curl_command_template.format(tok=tok, fromCityId=fromCityId, toCityId=toCityId, date=next_day,operator_id=operator_id,route_id=route_id)    
    return curl_command

#step-2:changing my curl request to response.json
#this function takes curl command as input and returns data of json file we can take json data of particualr curl
def curl_to_response_json(curl_command):
    tokens = shlex.split(curl_command)
    headers, data, url = {}, None, None
    it = iter(tokens)
    for token in it:
        if token == 'curl': continue
        elif token.startswith('http'): url = token
        elif token in ['-X', '--request']: method = next(it).upper()
        elif token in ['-H', '--header']: header = next(it); key, value = header.split(':', 1); headers[key.strip()] = value.strip()
        elif token in ['-d', '--data', '--data-raw', '--data-binary']: data = next(it)
    if headers.get('Content-Type') == 'application/json' and data: data = json.loads(data)
    for attempt in range(5):
        response = requests.post(url, headers=headers, json=data)
        if response.status_code == 200: return response.json()
        elif response.status_code == 404: print("404 Not Found."); return None
        else: print(f"Attempt {attempt+1}: Error {response.status_code}"); time.sleep(2)
    print("Failed to retrieve data after 5 attempts."); return None

#step-3:saving my json file to my required format csv file
#takes data as input which is assumed to be a json file and saving the output csv file  
def response_json_to_required_csv_format(data,directory_for_saving_seat_data_of_particular_route,operator_id,route_id):
    # Navigate to the 'seatlist' which contains the relevant data
    seatlist = data.get('seatlist', [])

    # Prepare a list to hold the data
    extracted_data = []

    # Extract data from each seat
    for seat in seatlist:
        fares_amount = seat.get('fares', {}).get('amount', None)
        id = seat.get('Id', None)
        is_available = seat.get('IsAvailable', None)
        
        # Append the extracted data as a tuple to the list
        extracted_data.append((id, fares_amount, is_available))

    # Convert the list of tuples into a DataFrame
    df = pd.DataFrame(extracted_data, columns=['seat', 'Fares_Amount', 'Is_Available'])
    df['occupied'] = df['Is_Available'].apply(lambda x: 0 if x else 1)
    df['revenue'] = df['Fares_Amount'] * df['occupied']
    final_revenue = df['revenue'].sum()

    # Add a final row with the total revenue
    final_row = pd.DataFrame({
        'seat': ['Total'],
        'Fares_Amount': ['-'],
        'Is_Available': ['-'],
        'occupied': ['-'],
        'revenue': [final_revenue]
    })

    # Append the row to the DataFrame
    df = pd.concat([df, final_row], ignore_index=True)

    # Get the current date and time
    current_datetime = datetime.datetime.now()

    # Format the current date and time
    formatted_datetime = current_datetime.strftime("%I.%M%p,%d-%m-%Y")
    travels_name = data.get('Travels', 'Unknown_Travel')
    now=datetime.datetime.now()
    fromcity=data.get('FromCity','Unkown_city')
    tocity=data.get('ToCity','Unkown_city')
    now = now.strftime("%I%p") 
    file_name_format = f"{travels_name}_{operator_id}_{route_id}_{fromcity}_{tocity}_seat_data_on_{formatted_datetime}_at_{now}.csv"
    #filename changed for convinece here
    #from     file_name_format = f"{travels_name}_{operator_id}_{route_id}_seat_data_on_{formatted_datetime}_at_{now}.csv"
    #to     file_name_format = f"seat_data_on_{formatted_datetime}_at_{now}.csv"


    os.makedirs(directory_for_saving_seat_data_of_particular_route, exist_ok=True)

    # Generate the file name
    file_name = os.path.join(directory_for_saving_seat_data_of_particular_route,file_name_format )

    try:
       df.to_csv(file_name, index=False)
       print(f"Data extraction complete and saved to '{file_name}'.")
    except Exception as e:
       print(f"Failed to save data to '{file_name}': {e}")   


def process_single_route(file_path):
    df = pd.read_csv(file_path)
    df = df[:-2]
    output_directory = os.path.join(output_dir, os.path.splitext(os.path.basename(file_path))[0])
    os.makedirs(output_directory, exist_ok=True)
    for index, row in df.iterrows():
        tok = 62480135398
        operator_id = int(row['operatorId'])
       # print(operator_id)
        route_id = int(row['routeId'])
       # print(route_id)
        fromCityId = cities[src_name]
       # print(fromCityId)
        toCityId = cities[dst_name]        
       # print(toCityId)
        if not np.isnan(fromCityId) and not np.isnan(toCityId):
          curl_command = generate_curl_command(tok, fromCityId, toCityId, operator_id, route_id)
          data = curl_to_response_json(curl_command)
          if data:
            response_json_to_required_csv_format(data, output_directory,operator_id,route_id)
          else:
            print(f"Failed to retrieve data for row index {index}")

process_single_route(buses_csv_file_path)
print("sucesfully fetched data :)")
# Out:
# Attempt 1: Error 417
# Attempt 2: Error 417
# Attempt 3: Error 417
# Attempt 4: Error 417
# Attempt 5: Error 417
# Failed to retrieve data after 5 attempts.
# Failed to retrieve data for row index 0
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Jabbar  Travels_8336_5017537_Hyderabad_Pune_seat_data_on_10.31AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Go Tour Travels and Holidays_25286_23232955_Hyderabad_Pune_seat_data_on_10.31AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Zingbus Plus_20218_30321197_Hyderabad_Pune_seat_data_on_10.31AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Go Tour Travels and Holidays_25286_22941333_Hyderabad_Pune_seat_data_on_10.31AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Go Tour Travels and Holidays_25286_22941334_Hyderabad_Pune_seat_data_on_10.31AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Ramana Tours And Travels_9138_26388207_Hyderabad_Pune_seat_data_on_10.31AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Jabbar  Travels_8336_5017539_Hyderabad_Pune_seat_data_on_10.31AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\IntrCity SmartBus_20437_17480145_Hyderabad_Pune_seat_data_on_10.31AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Go Tour Travels and Holidays_25286_22941335_Hyderabad_Pune_seat_data_on_10.31AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\LIMOLINER_16292_14185513_Hyderabad_Pune_seat_data_on_10.31AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Sangitam Travels Tanzanite_16182_28840265_Hyderabad_Pune_seat_data_on_10.31AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\IntrCity SmartBus_20437_28144888_Hyderabad_Pune_seat_data_on_10.31AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\EXEL RIDES_22595_21498267_Hyderabad_Pune_seat_data_on_10.31AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\IntrCity SmartBus_20437_16315966_Hyderabad_Pune_seat_data_on_10.31AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Jabbar  Travels_8336_5017535_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Dolphin  travel  house_3774_26942840_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\PVS Tours and Travels_16017_20899767_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Tanaaz Travels_22267_22271169_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Orange Tours And Travels_18112_21508766_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Dolphin  travel  house_3774_29359130_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Shreyash Travels_20130_19054528_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Orange Tours and Travels Grand_18112_12329929_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\RAJA EXPRESS_22049_26092466_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Dolphin  travel  house_3774_29728800_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Orange Tours And Travels_18112_16429674_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Indian express_16370_10260556_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\JAGUAR TRAVELS_29963_29753149_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\JAGUAR TRAVELS_29963_29755073_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Tanaaz Travels (Gajal Raj)_22267_29133505_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Orange Tours And Travels_18112_29960229_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\IntrCity SmartBus_20437_17072335_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Muskan Travels_29681_29242852_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Gujarat Travels_8473_12651161_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Orange Tours And Travels_18112_16026346_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Citizen Bus_4273_27142425_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Orange Tours And Travels_18112_16026345_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\R National Travels_23154_23995648_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Morning Star Travels_20397_17319868_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Dolphin  travel  house_3774_27679429_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\R National Travels_23154_31037118_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\PVS Tours and Travels_16017_28862862_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Citizen Bus_4273_23835091_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\JAGUAR TRAVELS_29963_29712991_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Dolphin  travel  house_3774_30436490_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Orange Tours and Travels Grand_18112_16972561_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\MY YATRA BUS_29567_30318681_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Citizen Bus_4273_18714457_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\DHANUNJAYA TRAVELS_29331_31056891_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Prasanna - Purple Bus_9748_30804338_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\IntrCity SmartBus_20437_31463558_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Sangita Travels_16085_17428201_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\SHRI GANESH TRAVELLS BARMER_22091_28379941_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Hans Travels (I) Private Limited_8842_30973108_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Hans Travels (I) Private Limited_8842_20853298_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\SRT Tours And Travels_18114_12306114_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Best Express_22055_22154170_Hyderabad_Pune_seat_data_on_10.32AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Best Express_22055_24729086_Hyderabad_Pune_seat_data_on_10.33AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\New Amar Travels_20371_24260781_Hyderabad_Pune_seat_data_on_10.33AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Best Express_22055_19308705_Hyderabad_Pune_seat_data_on_10.33AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\DHANUNJAYA TRAVELS_29331_28423201_Hyderabad_Pune_seat_data_on_10.33AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\New Blossom Tour And  Travels_18013_23208069_Hyderabad_Pune_seat_data_on_10.33AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\S B Travels_22648_31305067_Hyderabad_Pune_seat_data_on_10.33AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\DHANUNJAYA TRAVELS_29331_30926237_Hyderabad_Pune_seat_data_on_10.33AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\KGN Tours And Travels_9003_31233006_Hyderabad_Pune_seat_data_on_10.33AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Mythri Tours And Travels_19695_31504286_Hyderabad_Pune_seat_data_on_10.33AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\IntrCity SmartBus_20437_31464300_Hyderabad_Pune_seat_data_on_10.33AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\DHANUNJAYA TRAVELS_29331_30213604_Hyderabad_Pune_seat_data_on_10.33AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Deepak Travells_20142_30769365_Hyderabad_Pune_seat_data_on_10.33AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\S B Travels_22648_31525284_Hyderabad_Pune_seat_data_on_10.33AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\Best Express_22055_22556883_Hyderabad_Pune_seat_data_on_10.33AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\SRI SAI LUCKY TRAVELS_21973_24693778_Hyderabad_Pune_seat_data_on_10.33AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\KGN Tours And Travels_9003_31544163_Hyderabad_Pune_seat_data_on_10.33AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\VRL Travels_25338_29273578_Hyderabad_Pune_seat_data_on_10.33AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\VRL Travels_25338_28200178_Hyderabad_Pune_seat_data_on_10.33AM,09-07-2024_at_10AM.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\buses_on_14-Jul-2024_at_10AM,09-07-2024\VRL Travels_25338_29946427_Hyderabad_Pune_seat_data_on_10.33AM,09-07-2024_at_10AM.csv'.
# sucesfully fetched data :)

# %%
#2 saving seat data of each bus in diffrent directories
#input for cell : csv file contining different buses
now=datetime.datetime.now()
now = now.strftime("%I%p,%d-%m-%Y")           
filename = f"buses_on_{next_day}_at_{now}.csv"
buses_csv_file_path  = os.path.join(main_filepath,filename)

dummyfilename=f"buses_on_{next_day}"
output_dir=os.path.join(main_filepath,dummyfilename)


#step-1:first setting our curl command
#this function takes tok, fromCityId, toCityId,operator_id,route_id as input and returns curl command important thing for using this function is giving token input argumrnt for the function as it is not taken from any exterior csv files by default im giving token as some value
def generate_curl_command(tok, fromCityId, toCityId,operator_id,route_id):
    # Calculate the next day's date
    #next_day = (datetime.datetime.now() + datetime.timedelta(days=delay_days)).strftime('%d-%b-%Y')    
    # Base cURL command template
    curl_command_template = '''
    curl 'https://www.redbus.in/search/seatlayout/{route_id}/{date}/{operator_id}?isRedDealApplicable=false&tok={tok}&srcCountry=IND&InvPos=1' \
      -H 'accept: application/json, text/plain, */*' \
      -H 'accept-language: en-US,en;q=0.9' \
      -H 'cookie: jfpj=386e43f4851d3c7d15936f880c19eeb7; _gcl_au=1.1.1651692991.1715575898; tvc_smc_bus=google / organic / (not set); mriClientId=WD5c509415-c921-4880-ab5b-ad9a968ccd55; gClId=1195023281.1715575899; rtcInline=V2; dynamic_custinfo=V1; srcCountry=IND; destCountry=IND; _fbp=fb.1.1715575924793.1120299924; srpUserTypeVal=GUEST; singleSeatCoachMark=2; rbuuid=512ed1b0-110b-11ef-98bc-155d27275705; userSessionId=ID_hd5t56d1l; rb_fpData=%7B%22browserName%22%3A%22Chrome%22%2C%22browserVersion%22%3A%22125.0.0.0%22%2C%22os%22%3A%22Windows%22%2C%22osVersion%22%3A%2210%22%2C%22screenSize%22%3A%221536%2C816%22%2C%22screenDPI%22%3A1.25%2C%22screenResolution%22%3A%221920x1080%22%2C%22screenColorDepth%22%3A24%2C%22aspectRatio%22%3A%2216%3A9%22%2C%22systemLanguage%22%3A%22en-US%22%2C%22connection%22%3A%224g%22%2C%22userAgent%22%3A%22mozilla/5.0%20%28windows%20nt%2010.0%3B%20win64%3B%20x64%29%20applewebkit/537.36%20%28khtml%2C%20like%20gecko%29%20chrome/125.0.0.0%20safari/537.36%7CWin32%7Cen-US%22%2C%22timeZone%22%3A5.5%7D; PrimoDetails=%7B%22lastUpdated%22%3A%222024-05-13%22%2C%22lastShown%22%3A%222024-05-21%22%7D; country=IND; currency=INR; defaultlanguage=en; language=en; selectedCurrency=INR; abExps=["rtcInline","dynamic_custinfo"]; abExpsVariants=rtcInline:V2?dynamic_custinfo:V1; tvc_session_alive_bus=1; _gid=GA1.2.319393201.1716373399; _gat_UA-9782412-15=1; _dc_gtm_UA-9782412-15=1; reqOrigin=IND; mriClientIdSetDate=5%2F22%2F24%2010%3A23%3A18%20AM; bCore=1; defaultCountry=IND; deviceSessionId=9ac6deb2-0de7-4b20-bfe8-89d368afde55; mriSessionId=WD64475fb4-f557-48b7-83d0-b25b93f53db5; lzFlag=0; ak_bmsc=E38D836E2B2730F2D6C6BB99391EECB8~000000000000000000000000000000~...; moe_uuid=753cb754-3e23-4350-bf29-e4520bf8dd35; isBrowserFP=true; Branch_BrowserFingerPrintID=1216998847458037070; CountryName=INDIA; _ga=GA1.2.1195023281.1715575899; searchId=9cbe2c87741b4254b9532dde86b82a97; bm_sv=089DFD73A6BC507E91CD2DF0A0D29533~~1; resumeBook=true; _ga_3NXW5V9V8S=GS1.2.1716373399.28.1.1716373424.35.0.0; _VTok={tok}; _ga_1SE754V89Y=GS1.1.1716373398.36.1.1716373424.34.0.117391036' \
      -H 'referer: https://www.redbus.in/search?fromCityId={fromCityId}&srcCountry=IND&toCityId={toCityId}&destCountry=IND&onward={date}&opId=0&busType=Any' \
      -H 'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36' \
 '''
    # Format the cURL command with the provided arguments
    curl_command = curl_command_template.format(tok=tok, fromCityId=fromCityId, toCityId=toCityId, date=next_day,operator_id=operator_id,route_id=route_id)    
    return curl_command

#step-2:changing my curl request to response.json
#this function takes curl command as input and returns data of json file we can take json data of particualr curl
def curl_to_response_json(curl_command):
    tokens = shlex.split(curl_command)
    headers, data, url = {}, None, None
    it = iter(tokens)
    for token in it:
        if token == 'curl': continue
        elif token.startswith('http'): url = token
        elif token in ['-X', '--request']: method = next(it).upper()
        elif token in ['-H', '--header']: header = next(it); key, value = header.split(':', 1); headers[key.strip()] = value.strip()
        elif token in ['-d', '--data', '--data-raw', '--data-binary']: data = next(it)
    if headers.get('Content-Type') == 'application/json' and data: data = json.loads(data)
    for attempt in range(5):
        response = requests.post(url, headers=headers, json=data)
        if response.status_code == 200: return response.json()
        elif response.status_code == 404: print("404 Not Found."); return None
        else: print(f"Attempt {attempt+1}: Error {response.status_code}"); time.sleep(2)
    print("Failed to retrieve data after 5 attempts."); return None

#step-3:saving my json file to my required format csv file
#takes data as input which is assumed to be a json file and saving the output csv file  
def response_json_to_required_csv_format(data,directory_for_saving_seat_data_of_particular_route,operator_id,route_id):
    # Navigate to the 'seatlist' which contains the relevant data
    seatlist = data.get('seatlist', [])

    # Prepare a list to hold the data
    extracted_data = []

    # Extract data from each seat
    for seat in seatlist:
        fares_amount = seat.get('fares', {}).get('amount', None)
        id = seat.get('Id', None)
        is_available = seat.get('IsAvailable', None)
        
        # Append the extracted data as a tuple to the list
        extracted_data.append((id, fares_amount, is_available))

    # Convert the list of tuples into a DataFrame
    df = pd.DataFrame(extracted_data, columns=['seat', 'Fares_Amount', 'Is_Available'])
    df['occupied'] = df['Is_Available'].apply(lambda x: 0 if x else 1)
    df['revenue'] = df['Fares_Amount'] * df['occupied']
    final_revenue = df['revenue'].sum()

    travels_name = data.get('Travels', 'Unknown_Travel')
    fromcity=data.get('FromCity','Unkown_city')
    tocity=data.get('ToCity','Unkown_city')
    

    # Add a final row with the total revenue
    final_row = pd.DataFrame({
        'seat': ['Travels Name','journey route','Total'],
        'Fares_Amount': ['','',''],
        'Is_Available': ['','',''],
        'occupied': ['','',''],
        'revenue': [f'{travels_name}',f'{fromcity}-{tocity}',final_revenue]
    })

    # Append the row to the DataFrame
    df = pd.concat([df, final_row], ignore_index=True)

    # Get the current date and time
    current_datetime = datetime.datetime.now()

    # Format the current date and time
 #   formatted_datetime = current_datetime.strftime("%I.%M%p,%d-%m-%Y")
    
    now=datetime.datetime.now()    
    now = now.strftime("%I.%M%p,%d-%m-%Y") 
    file_name_format = f"{operator_id}_{route_id}_{now}.csv"
    #filename changed for convinece here
    #from     file_name_format = f"{travels_name}_{operator_id}_{route_id}_seat_data_on_{formatted_datetime}_at_{now}.csv"
    #to     file_name_format = f"seat_data_on_{formatted_datetime}_at_{now}.csv"


    os.makedirs(directory_for_saving_seat_data_of_particular_route, exist_ok=True)

    # Generate the file name
    file_name = os.path.join(directory_for_saving_seat_data_of_particular_route,file_name_format )

    try:
       df.to_csv(file_name, index=False)
       print(f"Data extraction complete and saved to '{file_name}'.")
    except Exception as e:
       print(f"Failed to save data to '{file_name}': {e}")   


def process_single_route(file_path):
    df = pd.read_csv(file_path)
    df = df[:-2]

    for index, row in df.iterrows():
        tok = 62480135398
        operator_id = int(row['operatorId'])
       # print(operator_id)
        route_id = int(row['routeId'])
       # print(route_id)
        fromCityId = cities[src_name]
       # print(fromCityId)
        toCityId = cities[dst_name]        
       # print(toCityId)
        output_directory = os.path.join(output_dir, f"{row['travelsName']}_{operator_id}_{route_id}")
        os.makedirs(output_directory, exist_ok=True)
        if not np.isnan(fromCityId) and not np.isnan(toCityId):
          curl_command = generate_curl_command(tok, fromCityId, toCityId, operator_id, route_id)
          data = curl_to_response_json(curl_command)
          if data:
            response_json_to_required_csv_format(data, output_directory,operator_id,route_id)
          else:
            print(f"Failed to retrieve data for row index {index}")

process_single_route(buses_csv_file_path)
print("sucesfully fetched data :)")
# Out:
# Attempt 1: Error 417
# Attempt 2: Error 417
# Attempt 3: Error 417
# Attempt 4: Error 417
# Attempt 5: Error 417
# Failed to retrieve data after 5 attempts.
# Failed to retrieve data for row index 0
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\Jabbar  Travels_8336_5017537\8336_5017537_10.34AM,09-07-2024.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\Go Tour Travels and Holidays_25286_23232955\25286_23232955_10.34AM,09-07-2024.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\Zingbus Plus_20218_30321197\20218_30321197_10.34AM,09-07-2024.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\Go Tour Travels and Holidays_25286_22941333\25286_22941333_10.34AM,09-07-2024.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\Go Tour Travels and Holidays_25286_22941334\25286_22941334_10.34AM,09-07-2024.csv'.
# Data extraction complete and saved to 'C:\Users\T VIJAYA BALAJI\Desktop\final_data_collection\Hyderabad_to_Pune\data_on_14-Jul-2024\buses_on_14-Jul-2024\Ramana Tours And Travels_9138_26388207\9138_26388207_10.34AM,09-07-2024.csv'.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 141
#     138           else:
#     139             print(f"Failed to retrieve data for row index {index}")
# --> 141 process_single_route(buses_csv_file_path)
#     142 print("sucesfully fetched data :)")
#
# Cell In[6], line 135, in process_single_route(file_path)
#     133 if not np.isnan(fromCityId) and not np.isnan(toCityId):
#     134   curl_command = generate_curl_command(tok, fromCityId, toCityId, operator_id, route_id)
# --> 135   data = curl_to_response_json(curl_command)
#     136   if data:
#     137     response_json_to_required_csv_format(data, output_directory,operator_id,route_id)
#
# Cell In[6], line 44, in curl_to_response_json(curl_command)
#      42 if headers.get('Content-Type') == 'application/json' and data: data = json.loads(data)
#      43 for attempt in range(5):
# ---> 44     response = requests.post(url, headers=headers, json=data)
#      45     if response.status_code == 200: return response.json()
#      46     elif response.status_code == 404: print("404 Not Found."); return None
#
# File c:\Users\T VIJAYA BALAJI\anaconda3\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\T VIJAYA BALAJI\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\T VIJAYA BALAJI\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\T VIJAYA BALAJI\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\T VIJAYA BALAJI\anaconda3\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\T VIJAYA BALAJI\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File c:\Users\T VIJAYA BALAJI\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\T VIJAYA BALAJI\anaconda3\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File c:\Users\T VIJAYA BALAJI\anaconda3\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File c:\Users\T VIJAYA BALAJI\anaconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\T VIJAYA BALAJI\anaconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\T VIJAYA BALAJI\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Users\T VIJAYA BALAJI\anaconda3\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\T VIJAYA BALAJI\anaconda3\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:
